# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('players_20.csv')

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(45), object(43)
# memory usage: 14.5+ MB

# %%
for col in df.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
df.shape
# Out:
# (18278, 104)

# %%
df.nationality.value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
df.nationality.value_counts()[0:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
country_names = df['nationality'].value_counts()[0:10].keys()

# %%
plt.figure(figsize=(16,8))
plt.bar(list(country_names),df['nationality'].value_counts()[0:10],color = ['orange'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
player_salary = df[['short_name','wage_eur']]

# %%
player_salary.head(10)
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000
# 5       K. De Bruyne    370000
# 6      M. ter Stegen    250000
# 7        V. van Dijk    200000
# 8          L. Modrić    340000
# 9           M. Salah    240000

# %%
player_salary = player_salary.sort_values(by=['wage_eur'],ascending = False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color = 'g')
plt.show()

# %%
df['nationality'] == 'Portugal'
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
Portugal = df[df['nationality'] == 'Portugal']
Portugal.head()
# Out:
#      sofifa_id                                         player_url  \
# 1        20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 41      218667  https://sofifa.com/player/218667/bernardo-mota...
# 85      212198  https://sofifa.com/player/212198/bruno-miguel-...
# 86      199482  https://sofifa.com/player/199482/anthony-lopes...
# 112     210514  https://sofifa.com/player/210514/joao-pedro-ca...
#
#             short_name                                long_name  age  \
# 1    Cristiano Ronaldo      Cristiano Ronaldo dos Santos Aveiro   34
# 41      Bernardo Silva  Bernardo Mota Veiga de Carvalho e Silva   24
# 85     Bruno Fernandes            Bruno Miguel Borges Fernandes   24
# 86            A. Lopes                            Anthony Lopes   28
# 112       João Cancelo                João Pedro Cavaco Cancelo   25
#
#             dob  height_cm  weight_kg nationality                club  ...  \
# ...

# %%
Portugal.shape
# Out:
# (344, 104)

# %%
Portugal.sort_values(by=['height_cm'],ascending = False).head()
# Out:
#        sofifa_id                                         player_url  \
# 7790      251616  https://sofifa.com/player/251616/david-mota-te...
# 6754      240847  https://sofifa.com/player/240847/leonardo-mira...
# 9309      213646  https://sofifa.com/player/213646/miguel-aires-...
# 7006      198511  https://sofifa.com/player/198511/michael-simoe...
# 11173     252200  https://sofifa.com/player/252200/diogo-fesnard...
#
#             short_name                       long_name  age         dob  \
# 7790       David Carmo       David Mota Teixeira Carmo   19  1999-07-19
# 6754    Leonardo Rocha          Leonardo Miramar Rocha   21  1997-08-23
# 9309   Miguel Oliveira  Miguel Aires Fernandes Olivera   25  1994-05-25
# 7006              Mika        Michael Simões Domingues   28  1991-03-08
# 11173      Diogo Sousa    Diogo Fesnard Nogueira Sousa   20  1998-09-16
#
#        height_cm  weight_kg nationality               club  ...   lwb   ldm  \
# ...

# %%
Portugal.sort_values(by=['weight_kg'],ascending = False).head()
# Out:
#       sofifa_id                                         player_url  \
# 9309     213646  https://sofifa.com/player/213646/miguel-aires-...
# 4145     210385  https://sofifa.com/player/210385/rui-tiago-dan...
# 7006     198511  https://sofifa.com/player/198511/michael-simoe...
# 5161     193143  https://sofifa.com/player/193143/roderick-j-go...
# 4607     199674  https://sofifa.com/player/199674/jorge-filipe-...
#
#             short_name                       long_name  age         dob  \
# 9309   Miguel Oliveira  Miguel Aires Fernandes Olivera   25  1994-05-25
# 4145         Rui Silva       Rui Tiago Dantas da Silva   25  1994-02-07
# 7006              Mika        Michael Simões Domingues   28  1991-03-08
# 5161  Roderick Miranda   Roderick J. Gonçalves Miranda   28  1991-03-30
# 4607    Jorge Teixeira   Jorge Filipe Avelino Teixeira   32  1986-08-27
#
#       height_cm  weight_kg nationality                     club  ...   lwb  \
# ...

# %%
Portugal.sort_values(by=['wage_eur'],ascending = False).head()
# Out:
#      sofifa_id                                         player_url  \
# 1        20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 41      218667  https://sofifa.com/player/218667/bernardo-mota...
# 112     210514  https://sofifa.com/player/210514/joao-pedro-ca...
# 249     227928  https://sofifa.com/player/227928/nelson-cabral...
# 129     162347  https://sofifa.com/player/162347/joao-filipe-m...
#
#             short_name                                long_name  age  \
# 1    Cristiano Ronaldo      Cristiano Ronaldo dos Santos Aveiro   34
# 41      Bernardo Silva  Bernardo Mota Veiga de Carvalho e Silva   24
# 112       João Cancelo                João Pedro Cavaco Cancelo   25
# 249      Nélson Semedo                     Nélson Cabral Semedo   25
# 129      João Moutinho         João Filipe Iria Santos Moutinho   32
#
#             dob  height_cm  weight_kg nationality                     club  \
# ...

# %%
Portugal[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending = False).head()
# Out:
#             short_name  wage_eur
# 1    Cristiano Ronaldo    405000
# 41      Bernardo Silva    210000
# 112       João Cancelo    150000
# 249      Nélson Semedo    150000
# 129      João Moutinho    125000

# %%
player_shooting = df[['short_name','shooting']]

# %%
player_shooting.sort_values(by=['shooting'],ascending = False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
player_defending = df[['short_name','defending','nationality','club']]

# %%
player_defending.sort_values(by = ['defending'],ascending = False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
fc_barcelona = df[df['club'] == 'FC Barcelona']

# %%
fc_barcelona.sort_values(by = ['wage_eur'],ascending = False).head()
# Out:
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 22     194765  https://sofifa.com/player/194765/antoine-griez...
# 19     176580  https://sofifa.com/player/176580/luis-suarez/2...
# 21     189511  https://sofifa.com/player/189511/sergio-busque...
# 29     152729  https://sofifa.com/player/152729/gerard-pique-...
#
#          short_name                       long_name  age         dob  \
# 0          L. Messi  Lionel Andrés Messi Cuccittini   32  1987-06-24
# 22     A. Griezmann               Antoine Griezmann   28  1991-03-21
# 19        L. Suárez        Luis Alberto Suárez Díaz   32  1987-01-24
# 21  Sergio Busquets        Sergio Busquets i Burgos   30  1988-07-16
# 29            Piqué           Gerard Piqué Bernabéu   32  1987-02-02
#
#     height_cm  weight_kg nationality          club  ...   lwb   ldm   cdm  \
# 0         170         72   Argentina  FC Barcelona  ...  68+2  66+2  66+2
# ...

# %%
fc_barcelona.sort_values(by = ['shooting'],ascending = False).head()
# Out:
#      sofifa_id                                         player_url  \
# 0       158023  https://sofifa.com/player/158023/lionel-messi/...
# 19      176580  https://sofifa.com/player/176580/luis-suarez/2...
# 22      194765  https://sofifa.com/player/194765/antoine-griez...
# 64      168651  https://sofifa.com/player/168651/ivan-rakitic/...
# 142     181872  https://sofifa.com/player/181872/arturo-vidal/...
#
#        short_name                       long_name  age         dob  height_cm  \
# 0        L. Messi  Lionel Andrés Messi Cuccittini   32  1987-06-24        170
# 19      L. Suárez        Luis Alberto Suárez Díaz   32  1987-01-24        182
# 22   A. Griezmann               Antoine Griezmann   28  1991-03-21        176
# 64     I. Rakitić                    Ivan Rakitić   31  1988-03-10        184
# 142      A. Vidal                    Arturo Vidal   32  1987-05-22        180
#
#      weight_kg nationality          club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
fc_barcelona.sort_values(by = ['defending'],ascending = False).head()
# Out:
#      sofifa_id                                         player_url  \
# 29      152729  https://sofifa.com/player/152729/gerard-pique-...
# 84      220440  https://sofifa.com/player/220440/clement-lengl...
# 59      205600  https://sofifa.com/player/205600/samuel-umtiti...
# 21      189511  https://sofifa.com/player/189511/sergio-busque...
# 142     181872  https://sofifa.com/player/181872/arturo-vidal/...
#
#           short_name                 long_name  age         dob  height_cm  \
# 29             Piqué     Gerard Piqué Bernabéu   32  1987-02-02        194
# 84        C. Lenglet           Clément Lenglet   24  1995-06-17        186
# 59         S. Umtiti             Samuel Umtiti   25  1993-11-14        182
# 21   Sergio Busquets  Sergio Busquets i Burgos   30  1988-07-16        189
# 142         A. Vidal              Arturo Vidal   32  1987-05-22        180
#
#      weight_kg nationality          club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...
